# %% [markdown]
# ## Matplotlib

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %% [markdown]
# Two ways to plot in matplotlib
# 1. Pyplot API (Commonly used) matplotlib.pyplot
# 2. object-oriented API
# 3. (The Pyplot API is generally less-flexible than object-oriented API.)

# %%
#1st method
fig=plt.figure() #create a figure
ax=fig.add_subplot()
plt.show()

# %%
#2nd methods
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
#3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x,y);

# %% [markdown]
# ## Matplolib Anatomies

# %% [markdown]
# ![](matplotlib-anatomy-of-a-plot.png)

# %% [markdown]
# ![](matplotlib-anatomy-of-a-plot-with-code.png)

# %%
## What is object oriented API
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# here I can see that fig has type matplotlib.figure.Figure like an OOPs concept in python and same goes for matplotlib.axes._axes.Axes

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter 
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x=[1,2,3,4]
y=[11,22,32,44]

# 2. Setup plot
fig,ax=plt.subplots(figsize=(10,10)) #(width,height)

# 3. plot data
ax.plot(x,y)

# 4. Customize plot
ax.set(title="Simple-Plot", xlabel="x-axis", ylabel='y-axis')

# 5. Save and share (you save the whole figure)
fig.savefig("./numpy-images/sample-plot.png")

# %% [markdown]
# ## making figures with Numpy arrays
#
# we want:
# * Line plot
# * scatter plot
# * Bar plot
# * Histogram
# * Subplot

# %%
#Create some data
x=np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
fig,ax=plt.subplots()
ax.plot(x,x**2);

# %%
#use the same data to make scatter plot
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x));

# %%
#Another scatter plot
fig, ax=plt.subplots()
ax.scatter(x,np.sin(x));

# %%
# make a plot from dictionary
nut_butter_prices = {"Almond butter": 10, 
                    "Peanut butter": 8, 
                    "cashew butter": 12}
fig,ax = plt.subplots()
ax.bar(x=list(nut_butter_prices.keys()),height=nut_butter_prices.values());

# %%
nut_butter_prices = {"Almond butter": 10, 
                    "Peanut butter": 8, 
                    "cashew butter": 12}
fig,ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values()) # (x,heights)
ax.set(title="Dan's nut butter store", ylabel="Price ($)");

# %%
fig, ax=plt.subplots()
ax.barh(list(nut_butter_prices.keys()),nut_butter_prices.values()); # (y,width)

# %%
# Make some data
x=np.random.randn(1000) # standard normal distribution 
fig,ax=plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options to subplot

# %%
#subplots option 1

fig, ((ax1,ax2), (ax3,ax4))= plt.subplots(nrows=2,
                                         ncols=2, 
                                         figsize=(10,5))

#plot to each different axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax4.hist(np.random.randn(10000));

# %%
# Subplots option 2
fig,ax = plt.subplots(nrows=2,
                     ncols=2,
                     figsize=(10,5))
#plot the each different index

ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.randint(10,size=(5)),np.random.randint(10,size=5));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(10000));

# %% [markdown]
# ## Plotting from Pandas DataFrames

# %%
#Make a dataFrame
import pandas as pd
import numpy as np
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts= pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2020",periods=1000))
ts
# Out:
# 2020-01-01   -0.284984
# 2020-01-02    1.472279
# 2020-01-03    1.298918
# 2020-01-04    1.086041
# 2020-01-05   -0.168492
#                 ...
# 2022-09-22   -0.496073
# 2022-09-23   -0.185314
# 2022-09-24    0.452465
# 2022-09-25   -3.117033
# 2022-09-26    0.443530
# Freq: D, Length: 1000, dtype: float64

# %%
ts =ts.cumsum() #Cumulative sum
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.Price=car_sales.Price.str.replace('[\.\$\,]',"").astype(int)
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_7628\2639085589.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales.Price=car_sales.Price.str.replace('[\.\$\,]',"").astype(int)

# %%
car_sales.Price=car_sales.Price//100

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"]=pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Cumulative Sales"]=car_sales.Price.cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Cumulative Sales
# 0  Toyota  White         150043      4   4000 2020-01-01              4000
# 1   Honda    Red          87899      4   5000 2020-01-02              9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03             16000
# 3     BMW  Black          11179      5  22000 2020-01-04             38000
# 4  Nissan  White         213095      4   3500 2020-01-05             41500
# 5  Toyota  Green          99213      4   4500 2020-01-06             46000
# 6   Honda   Blue          45698      4   7500 2020-01-07             53500
# 7   Honda   Blue          54738      4   7000 2020-01-08             60500
# 8  Toyota  White          60000      4   6250 2020-01-09             66750
# 9  Nissan  White          31600      4   9700 2020-01-10             76450

# %%
car_sales.plot(x="Sale Date", y="Cumulative Sales");

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %%
car_sales.plot("Odometer (KM)","Price",kind="bar");

# %%
car_sales.plot("Odometer (KM)","Price",kind="hist");

# %%
#How about a bar Graph
x = np.random.rand(10,4)
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.367772  0.335292  0.837410  0.384259
# 1  0.480816  0.537236  0.261310  0.402436
# 2  0.890199  0.497537  0.837683  0.335185
# 3  0.738666  0.663320  0.028714  0.456105
# 4  0.794299  0.833532  0.860992  0.784354
# 5  0.257299  0.669667  0.781680  0.733782
# 6  0.788639  0.560562  0.750292  0.238371
# 7  0.011499  0.119872  0.102211  0.246773
# 8  0.419669  0.702274  0.597447  0.897672
# 9  0.184499  0.087878  0.685023  0.662809

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales.plot(x="Make", y = "Odometer (KM)",kind="bar");

# %%
average_odometer_per_make=car_sales.groupby("Make")["Odometer (KM)"].mean()

# %%
average_odometer_per_make.plot(kind="bar");

# %%
#How about Histograms? 
#Histograms are great for visualizing distribution of data
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10);

# %%
# Try another Dataset

heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#Create a histogram of age column
heart_disease.age.plot.hist(bins=20);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.columns[0]
# Out:
# 'age'

# %%
fig,ax=plt.subplots(nrows=3,ncols=5,figsize=(20,10))
index=0
for i in range(3):
    for j in range(5):
        if index>=len(heart_disease.columns): 
            break
        ax[i,j].hist(heart_disease[heart_disease.columns[index]]);
        index+=1;

# %%
heart_disease.plot.hist(subplots=True,figsize=(5,30));

# %% [markdown]
# ### Which one should you use? (pyplot vs matplot oo methods? )
# * when plotting something quickly, okay to use pyplot method
# * when Plotting something advanced, use th OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50=heart_disease[heart_disease["age"]>50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
#pyplot method
over_50.plot(kind="scatter", 
            x='age', 
            y='chol', 
            c='target');

# %%
# OO method
fig,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',x='age',y='chol',
           c='target',ax=ax);
ax.set_xlim([45,100]);

# %%
## OO method from scratch

fig,ax= plt.subplots(figsize=(10,6))

#plot the data
scatter = ax.scatter(x=over_50['age'],y=over_50["chol"],c=over_50['target']);

#customize the plot
ax.set(title="Heart Disease and Cholesterol Levels", 
      xlabel="Age", 
      ylabel="Cholestrol");

#Add a legend
ax.legend(*scatter.legend_elements(),title="Target");

#Add a horizontal line
ax.axhline(over_50["chol"].mean(),linestyle='--',color='red');

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#subplot of chol, age, thalach

fig,(ax0,ax1)=plt.subplots(nrows=2,
                          ncols=1,
                          figsize=(10,10),
                          sharex=True);

# Add data to ax0
scatter = ax0.scatter(x=over_50['age'], 
                     y=over_50["chol"], 
                     c=over_50['target'])

#customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",  
       ylabel="Cholesterol")

#Add a legend to ax0
ax0.legend(*scatter.legend_elements(),title="Target")
#Add a meanline
ax0.axhline(over_50["chol"].mean(),linestyle='--',color='red');

#turn of ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"]);
#customize ax1
ax1.set(title = "Heart Disease and Max Heart Rate",
xlabel="Age",
       ylabel="max Heart Rate");
#adding legend
ax1.legend(*scatter.legend_elements(),title="Target");
#adding mean line
ax1.axhline(over_50["thalach"].mean(),linestyle="--",color='red');

#add a title to figure 
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %% [markdown]
# ## Customizing Matplotlib plots

# %%
#Different style of matplotlib
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
#not all types just example
fig,ax=plt.subplots(nrows=5,ncols=6,figsize=(20,20));
index=0
for i in range(5):
    for j in range(6):
        if index>=len(plt.style.available):
            break
        plt.style.use(plt.style.available[index]);
        ax[i,j].plot(car_sales.Price);
        index+=1;

# %%
plt.style.use("seaborn");
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_7628\369795069.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn");

# %%
car_sales["Price"].plot();

# %%
plt.style.use("ggplot")
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
#Create some data
x=np.random.randn(10,4);
x
# Out:
# array([[ 2.27392754,  0.129015  ,  1.30313222, -0.66537299],
#        [-0.58940836,  0.74139158, -0.69592023,  0.65560967],
#        [ 0.35528444, -0.03139177, -1.31914873, -0.88311898],
#        [-1.5990341 ,  1.2480869 , -0.37433217,  0.2890412 ],
#        [ 0.59055416,  0.18740659, -0.1314291 , -0.03135025],
#        [ 0.19154232, -0.33356632,  1.26143101, -1.29181501],
#        [ 0.2125768 ,  0.39391343, -1.22461078, -0.36254985],
#        [ 0.58237965,  0.21637091, -0.5901285 ,  0.14812499],
#        [ 0.5340278 , -0.48316374, -0.75056307, -2.52626691],
#        [-0.16975081, -0.30017758,  1.69047025,  1.97750311]])

# %%
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  2.273928  0.129015  1.303132 -0.665373
# 1 -0.589408  0.741392 -0.695920  0.655610
# 2  0.355284 -0.031392 -1.319149 -0.883119
# 3 -1.599034  1.248087 -0.374332  0.289041
# 4  0.590554  0.187407 -0.131429 -0.031350
# 5  0.191542 -0.333566  1.261431 -1.291815
# 6  0.212577  0.393913 -1.224611 -0.362550
# 7  0.582380  0.216371 -0.590128  0.148125
# 8  0.534028 -0.483164 -0.750563 -2.526267
# 9 -0.169751 -0.300178  1.690470  1.977503

# %%
ax = df.plot(kind="bar")
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
ax = df.plot(kind="bar")
ax.set(title="Random Nubmer Bar Graph from DataFrame", 
      xlabel="Row number", 
      ylabel="Random numbers")
ax.legend().set_visible(True)

# %%
# some more about customization 
## OO method from scratch
plt.style.use("seaborn-whitegrid");
fig,ax= plt.subplots(figsize=(10,6))

#plot the data
scatter = ax.scatter(x=over_50['age'],
                     y=over_50["chol"],
                     c=over_50['target'], 
                    cmap='winter'); # all is going to mean is this changes color scheme

#customize the plot
ax.set(title="Heart Disease and Cholesterol Levels", 
      xlabel="Age", 
      ylabel="Cholestrol");

#Add a legend
ax.legend(*scatter.legend_elements(),
          title="Target");

#Add a horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle='--',
           color='red');
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_7628\2698607622.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid");

# %%
# some more about customization 
## OO method from scratch
plt.style.use("seaborn-whitegrid");
fig,ax= plt.subplots(figsize=(10,6));

#plot the data
scatter = ax.scatter(x=over_50['age'],
                     y=over_50["chol"],
                     c=over_50['target'], 
                    cmap='summer'); # all is going to mean is this changes color scheme

#customize the plot
ax.set(title="Heart Disease and Cholesterol Levels", 
      xlabel="Age", 
      ylabel="Cholestrol");

#Add a legend
ax.legend(*scatter.legend_elements(),
          title="Target");

#Add a horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle='--',
           color='red');
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_7628\678138709.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid");

# %%
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_7628\2698607622.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid");

# %%
#subplot of chol, age, thalach
# plt.style.use("seaborn-v0_8-whitegrid")
fig,(ax0,ax1)=plt.subplots(nrows=2,
                          ncols=1,
                          figsize=(10,10),
                          sharex=True);

# Add data to ax0
scatter = ax0.scatter(x=over_50['age'], 
                     y=over_50["chol"], 
                     c=over_50['target'],
                     cmap="winter")
# ax0.xlim([])
#customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",  
       ylabel="Cholesterol")

#Add a legend to ax0
ax0.legend(*scatter.legend_elements(),title="Target")
#Add a meanline
ax0.axhline(over_50["chol"].mean(),linestyle='--',color='red');

#turn of ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"],
                     cmap="winter",
                     edgecolors='face');
#customize ax1
ax1.set(title = "Heart Disease and Max Heart Rate",
xlabel="Age",
       ylabel="max Heart Rate");
#adding legend
ax1.legend(*scatter.legend_elements(),title="Target");
#adding mean line
ax1.axhline(over_50["thalach"].mean(),linestyle="--",color='red');

#add a title to figure 
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %% [markdown]
# ## Save and Share the figure

# %%
fig.savefig("heart-disease-plot-save-with-code.png")
